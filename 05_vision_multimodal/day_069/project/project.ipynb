# %% [markdown]
# # Day 069 — Project: Image Extractor
#
# ## What You're Building
#
# `image_extractor.py` — an `ImageExtractor` class for schema-guided structured extraction from images using a vision LLM.
#
# **Deliverable:** A class that accepts a Pydantic model class at construction time and returns validated typed objects from any image.
#
# ## Setup
#
# ```bash
# ollama pull llava      # vision model
# ```
#
# ## Design
#
# ```
# ImageExtractor(schema_cls, model='llava', describe_fn=None)
#   .extract(img, retries=2) → validated Pydantic model instance
# ```
#
# ## Usage (with real Ollama)
#
# ```python
# from image_extractor import ImageExtractor
# from pydantic import BaseModel
# from PIL import Image
#
# class Receipt(BaseModel):
#     merchant: str
#     total:    float
#     items:    list[str] = []
#
# extractor = ImageExtractor(schema_cls=Receipt)
# img = Image.open('receipt.jpg')
# result = extractor.extract(img)
# print(result.merchant, result.total)
# ```

# %%
# Your implementation here
# Build ImageExtractor and write it to image_extractor.py
