# %% [markdown]
# # Day 015 Project — Multi-Turn CLI Chatbot
#
# **Deliverable:** Build a multi-turn CLI chatbot using all five functions from this day.
#
# ## What you build
#
# A complete chatbot that:
#
# 1. Sets a **system prompt** to define its persona (you choose)
# 2. Runs a **chat loop** that reads from `input()` and calls `chat_turn`
# 3. Supports **slash commands**: `/quit` (exit), `/reset` (clear history), `/history` (show transcript)
# 4. **Truncates history** after every turn to stay within the context window
# 5. Prints `Bot:` responses cleanly
#
# ## Acceptance criteria
#
# - [ ] Custom system prompt defining a persona
# - [ ] `append_turn`, `chat_turn`, `truncate_history`, `reset_history`, `format_history` all used
# - [ ] `/quit`, `/reset`, `/history` commands implemented
# - [ ] History truncated after every turn (max_turns=10 default)
# - [ ] Graceful exit on Ctrl+C
#
# ## Getting started
#
# See `project/solution/solution.ipynb` for a scripted demonstration of all five functions. The interactive `run_chatbot()` function is defined there but called in a non-interactive mode for gate compatibility.

# %%
import ollama

# Your chatbot implementation here
