# %% [markdown]
# # Day 56 Project: Doc-Upload AI App
#
# **What You're Building:**
#
# A FastAPI service (`doc_api.py`) that lets users upload `.txt` or `.pdf` files and then ask questions about them:
#
# - `POST /upload` — validate the file, extract its text, store it, return a `doc_id`
# - `GET /docs` — list all uploaded documents
# - `POST /ask/{doc_id}?question=...` — answer a question about the document using Ollama
#
# **Deliverable:** Run `uvicorn doc_api:app --reload`, upload a `.txt` or `.pdf` file via `/docs`, then call `/ask/{doc_id}` with a question. That's the deliverable — a working document Q&A service.

# %% [markdown]
# ## Your Implementation

# %%
# Project setup
from pathlib import Path
from starlette.testclient import TestClient

def write_doc_api(path: str) -> str:
    """Generate doc_api.py at path and return the path string.

    The generated file should contain a FastAPI app with:
      POST /upload       — validate + save + extract text, return {doc_id, filename, chars}
      GET  /docs         — list uploaded documents
      POST /ask/{doc_id} — answer a question about the document (calls Ollama)
    """
    # TODO: build _DOC_API_SRC as a string, then:
    # Path(path).write_text(_DOC_API_SRC, encoding="utf-8")
    # return path
    raise NotImplementedError

# %% [markdown]
# ## Check Your Work
#
# Implement `write_doc_api` above, then re-run.

# %%
print('Implement write_doc_api above, then re-run this cell.')
