# %% [markdown]
# # Day 2 Project: Contact List Cleaner
#
# ## What You're Building
#
# A utility that takes a **messy contacts file** (JSON) and produces a **clean, validated one** — plus a short report of what it did. You run it, and you get back tidy data you can trust.
#
# That's the deliverable: `clean_file(in_path, out_path)` following **Load → Clean → Validate → Save**.
#
# **Requirements**
# 1. **Load** the raw contacts from `in_path` (JSON: a list of records).
# 2. **Clean** each record with your `clean_record` from Exercise 5.
# 3. **Validate** — keep only records that have *both* a name and an email.
# 4. **Save** the clean records to `out_path` as indented JSON.
# 5. **Report** — return `{'total': N, 'kept': M, 'dropped': N-M}` and print it.

# %% [markdown]
# ### Sample messy data (run this first)
#
# This creates a messy input file to work with.

# %%
import json

messy = [
    {'name': '  ada  LOVELACE ', 'email': ' ADA@math.org '},
    {'name': 'alan turing',      'email': 'alan@bletchley.uk'},
    {'name': '  grace hopper',   'email': ''},          # missing email -> drop
    {'email': 'anon@nowhere.io'},                       # missing name  -> drop
    {'name': 'KATHERINE johnson','email': 'KJ@nasa.GOV '},
]
with open('contacts_raw.json', 'w') as f:
    json.dump(messy, f, indent=2)
print('Wrote contacts_raw.json with', len(messy), 'messy records.')

# %% [markdown]
# ## Your Implementation
#
# Build `clean_record` and `clean_file`, then run the utility on `contacts_raw.json`. Aim to keep 3 records and drop 2.

# %%
# Reuse your clean_record from Exercise 5, then build clean_file.

def clean_record(record: dict) -> dict:
    ...

def clean_file(in_path: str, out_path: str) -> dict:
    ...

# report = clean_file('contacts_raw.json', 'contacts_clean.json')
# print(report)

# %% [markdown]
# > Stuck? The full solution is in `solution/solution.ipynb` — but build it yourself first. You already wrote every piece across today's exercises.
