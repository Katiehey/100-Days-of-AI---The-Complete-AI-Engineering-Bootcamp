# %% [markdown]
# # Day 1 Project: Personal AI Briefing Generator
#
# ## What You're Building
#
# A Python script that takes a list of AI news headlines and generates a polished, spoken audio briefing — as if you had a personal news reader.
#
# You run it, it produces an MP3 you can actually listen to. That's the deliverable.
#
# ---
#
# ## Requirements
#
# Your script must:
#
# 1. **Accept a list of headlines** — at least 5, hardcoded in the script is fine
# 2. **Format them into a spoken script** — not just raw bullets. Add a proper intro, transition phrases between headlines, and an outro. It should sound natural when read aloud.
# 3. **Generate audio** using Edge TTS with Jenny's voice (`en-US-JennyNeural`)
# 4. **Save the file** with a timestamped filename, e.g. `briefing_20260706.mp3`
# 5. **Print a summary** after generation: filename, file size in KB, and estimated listening time in seconds
#
# ---
#
# ## Rules
#
# - Do **not** copy from `tts.py` or your Exercise 1 solution — write it fresh
# - Do **not** look at the solution file until you have a working version
# - You **can** refer to the edge-tts documentation or the code you've already read
# - The audio must actually play and sound like a real briefing
#
# ---
#
# ## How to Know It's Done
#
# - The script runs without errors
# - An MP3 file is created with the correct timestamped name
# - You play it and it sounds like a coherent news briefing with intro and outro
# - The printed summary shows a file size greater than 10 KB
#
# ---
#
# ## Sample Headlines (use these or write your own)
#
# ```
# - OpenAI releases new reasoning model with improved code generation
# - Google DeepMind's AlphaFold 3 predicts protein interactions with record accuracy
# - Anthropic raises funding to accelerate Constitutional AI research
# - Microsoft integrates AI coding assistant into Visual Studio Code natively
# - South African startup uses computer vision to detect crop disease in real time
# ```
#
# ---
#
# **When you're done:** open `solution/solution.ipynb` to compare your approach.

# %%
# Your implementation here
# Take your time — build it from scratch
