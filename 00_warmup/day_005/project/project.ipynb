# %% [markdown]
# # Day 5 Project: Harden the Day 3 Assistant
#
# **Goal:** Take the `ask()` function from Day 3 and harden it with all three
# engineering hygiene layers: logging, error handling, and tests.
#
# **Deliverable:** A `safe_ask()` function that:
# - Logs at DEBUG when called and at INFO on success
# - Returns a fallback string if Ollama is unavailable
# - Has two automated tests (happy path + error path)
#
# > Complete exercises 1–5 before starting this project.

# %% [markdown]
# ## Setup

# %%
import logging
import ollama

logging.basicConfig(
    level=logging.DEBUG,
    format="%(asctime)s %(levelname)-8s %(message)s",
)
logger = logging.getLogger(__name__)

MODEL = "llama3.2"
SYSTEM = "You are a helpful assistant. Answer concisely."

# %% [markdown]
# ## Part 1: Implement safe_ask
#
# Implement `safe_ask` with logging + error handling. Use the pattern from Exercise 5.

# %%
def safe_ask(question: str, fallback: str = "") -> str:
    # TODO: add logging at entry and exit
    # TODO: wrap ollama.chat in try/except
    # TODO: return fallback on exception (or raise if no fallback)
    pass

# %% [markdown]
# ## Part 2: Test safe_ask
#
# Write two test functions:
# - `test_safe_ask_returns_string` — happy path
# - `test_safe_ask_fallback_on_bad_model` — error path (patch MODEL to a bad value)

# %%
def test_safe_ask_returns_string():
    # TODO: call safe_ask with a simple question, assert result is str
    pass


def test_safe_ask_fallback_on_bad_model():
    # TODO: patch MODEL to 'no-such-model', call safe_ask with fallback,
    # assert the fallback string is returned
    pass

# %% [markdown]
# ## Part 3: Run Your Tests
#
# Call your test functions and see them pass.

# %%
test_safe_ask_returns_string()
print("test_safe_ask_returns_string passed")

test_safe_ask_fallback_on_bad_model()
print("test_safe_ask_fallback_on_bad_model passed")

print()
print("✅ All project tests passed!")
