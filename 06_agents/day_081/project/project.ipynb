# %% [markdown]
# # Day 081 — Project: A Multi-Tool Assistant
#
# ## Objective
#
# Build `tool_agent.py` — an assistant that routes each request to the best tool from a validated toolbox.
#
# ## Deliverable
#
# `tool_agent.py` with:
#
# - `DEFAULT_TOOLS` — a toolbox where each tool has a typed parameter schema
# - `validate_args(tool, args) -> (ok, error)`
# - `ToolRegistry` — `register/add/get/names/describe/validate/execute`
# - `build_default_registry()`
# - `build_selection_prompt(query, registry)` / `select_tool(...)`
# - `route_query(query, registry, llm_fn=None) -> dict`
# - `ToolAgent(registry=None, llm_fn=None)` with `add_tool/tools/ask/history/clear_history`
#
# ## Usage (with Ollama running + llama3.2 pulled)
#
# ```python
# from tool_agent import ToolAgent
# agent = ToolAgent()
# print(agent.ask('reverse the word hello')['result'])
# print(agent.ask('what is 19 * 23')['result'])
# ```
#
# **The deliverable:** you run it, and each request is routed to the right tool — validated, executed, and answered. Two guards (a real tool, valid args) stand between the model and every tool call.

# %%
# Your implementation here — build tool_agent.py
